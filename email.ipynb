# %%
import smtplib
import csv
import ssl
from email.message import EmailMessage
from pyhere import here
import pandas as pd
import numpy as np
from great_tables import GT as gt
from getpass import getpass

# %%
contact = pd.read_csv(here('fake_names_emails.csv'))
names = contact['name'].str.split(' ').str.len()

# %%
print(contact.head())
print('\n\n')
print(names)
print(contact.loc[0, 'email'])
# Out:
#                       name                              email
# 0         Jonathan Pedroza               cpppedroza@gmail.com
# 1       Jonathan A Pedroza   jonathan.pedroza.atlas@gmail.com
# 2  Jonathan Andrew Pedroza          jpedroza1228@berkeley.edu
#
#
#
# 0    2
# 1    3
# 2    3
# Name: name, dtype: int64
#  cpppedroza@gmail.com

# %%
pw = getpass('Enter your password: ')

# %%
import certifi

port = 465
my_email = 'cpppedroza@gmail.com'
context = ssl.create_default_context(cafile=certifi.where())

msg = EmailMessage()
msg.set_content("Hi,\n\nYou are receiving this email because you were flagged as a student that may not be proficient on this week's quiz content.\nAs a precaution, we are recommending that you spend some time reviewing the course material covered in this week's quiz. As a reminder, there are homework parties on ____ and office hours on _____.")
msg['Subject'] = 'Data89 Quiz 1 Proficiency'
msg['From'] = my_email
# msg['Bcc'] = list(contact['email'])
msg['Bcc'] = 'jpedroza1228@berkeley.edu'


with smtplib.SMTP_SSL('smtp.gmail.com',
                      port,
                      context = context) as server:
    server.login(my_email, pw)
    server.send_message(msg)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[20], line 11
#       6 context = ssl.create_default_context(cafile = certifi.where())
#       8 with smtplib.SMTP_SSL('smtp.gmail.com',
#       9                       port,
#      10                       context = context) as server:
# ---> 11     server.login(my_email, pw)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/smtplib.py:762, in SMTP.login(self, user, password, initial_response_ok)
#     759         last_exception = e
#     761 # We could not login successfully.  Return result of last attempt.
# --> 762 raise last_exception
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/smtplib.py:751, in SMTP.login(self, user, password, initial_response_ok)
#     749 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     750 try:
# --> 751     (code, resp) = self.auth(
#     752         authmethod, getattr(self, method_name),
#     753         initial_response_ok=initial_response_ok)
#     754     # 235 == 'Authentication successful'
#     755     # 503 == 'Error: already authenticated'
#     756     if code in (235, 503):
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/smtplib.py:669, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     667 if code in (235, 503):
#     668     return (code, resp)
# --> 669 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials a92af1059eb24-1244ad7201fsm22402689c88.7 - gsmtp')
